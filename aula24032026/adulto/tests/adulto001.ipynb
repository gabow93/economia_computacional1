# %%
""""
Programa adulto
Descricao: Este programa pergunta a idade de uma pessoa. Se a idade for maior do que 18 anos, o programa mprime na tela 'Oi, voce eh um adulto.'
Data: 24/03/2026
Versao: 0.0.1
"""
# Out:
# '"\nPrograma adulto\nDescricao: Este programa pergunta a idade de uma pessoa. Se a idade for maior do que 18 anos, o programa mprime na tela \'Oi, voce eh um adulto.\'\nData: 24/03/2026\nVersao: 0.0.1\n'

# %%
# Aloc de mem

age = 0
txt = ""

# %%
# Input

age = int(input('\n Qual a sua idade?'))
# Out:
#  Qual a sua idade? 21

# %%
# Process. dados

if age >= 18:
    txt = 'Oi, vc é um adulto'

# %%
# Output

print(txt)
# Out:
# Oi, vc é um adulto
